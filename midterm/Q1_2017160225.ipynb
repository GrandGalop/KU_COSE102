# %%
inputlist=input().split()
for i in range(0, len(inputlist)):
  inputlist[i]=int(inputlist[i])
listsum=sum(inputlist)
for i in range(0, len(inputlist)):
  if inputlist[i]>1.5*(listsum-inputlist[i])/(len(inputlist)-1):
    print(inputlist[i])
    break
else:
  print("Not Found")
# Out:
# 20 20 30 30 30
# Not Found
